# %% [markdown]
# ### LSTM Attention

# %%
import os
import pathlib
current_dir = pathlib.Path.cwd()
parent_dir = current_dir.parent
preprocessing_output_dir = pathlib.Path('{}/1_preprocessing_all_domain/output_temp'.format(parent_dir))
output_dir = pathlib.Path('{}/output_temp'.format(current_dir))
pathlib.Path.mkdir(output_dir, mode=0o777, exist_ok=True)
print(current_dir)
# Out:
# d:\GIT_CODE\CDM_LSTM\2_lstm_attention_all_domain

# %%
with open('{}/0_importsql/abnormal_list.txt'.format(parent_dir), 'r') as f:
    data = f.read()
outcome_name_list = data.splitlines()
outcome_name_list=['abnormal_hepatotoxicity', 'abnormal_nephrotoxicity']

# %%
def split_x_y_data(df, OBP) :
    import numpy as np
    import pandas as pd

    y_data = df['label'].T.reset_index(drop=True) #df['label'].T.drop_duplicates().T.reset_index(drop=True)
    y_data = np.array(y_data)
    y_data = y_data[0:len(y_data):OBP].reshape(-1, 1).astype(int)
    #print(len(y_data), file=_logfile_)

    x_df = df.drop('label', axis=1)

    # 2-d data to 3-d data
    timestamp = OBP 
    x_data = np.array(x_df)
    x_data = x_data.reshape(-1, timestamp, x_data.shape[1]) # -1(sample), timestamp, column
    #x_data.shape, y_data.shape

    # get Column data
    new_col = x_df.columns
    print(x_data.shape, y_data.shape, len(new_col))
    return x_data, y_data, new_col

# %% [markdown]
# # Model Load

# %%
# for linux
import os
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"

# %%
import os
import pickle
from tqdm import tqdm
from Auto_lstm_attention import *
c = Auto_lstm_attention()
error=[]

for outcome_name in tqdm(outcome_name_list):
    #try:
        # 결과물 저장할 폴더 생성
        output_domain_path = pathlib.Path('{}/{}'.format(output_dir, outcome_name))
        pathlib.Path.mkdir(output_domain_path, mode=0o777, parents=True, exist_ok=True)
                
        concat_df = pd.read_csv('{}/{}.txt'.format(preprocessing_output_dir, outcome_name), index_col=False)
        
        # ##### Case 1 : Split by subject_id #####
        # id_data = concat_df[['subject_id', 'label']].drop_duplicates().reset_index(drop=True)
        # x_id_data = np.array(id_data['subject_id'])
        # y_id_data = np.array(id_data['label'])
        
        # x_id_train, x_id_test, y_id_train, y_id_test = train_test_split(x_id_data, y_id_data, test_size=0.3, random_state=1, stratify=y_id_data) 
        
        # train_df = concat_df[concat_df['subject_id'].isin(x_id_train)].reset_index(drop=True)
        # test_df = concat_df[concat_df['subject_id'].isin(x_id_test)].reset_index(drop=True)
        
        # train_df.to_csv('{}/{}_train.txt'.format(output_domain_path, outcome_name), index=False)
        # test_df.to_csv('{}/{}_test.txt'.format(output_domain_path, outcome_name), index=False)
        
        # concat_df = concat_df.drop(['subject_id', 'unique_id', 'cohort_start_date', 'concept_date', 'first_abnormal_date'], axis=1)
        # train_df = train_df.drop(['subject_id', 'unique_id', 'cohort_start_date', 'concept_date', 'first_abnormal_date'], axis=1)
        # test_df = test_df.drop(['subject_id', 'unique_id', 'cohort_start_date', 'concept_date', 'first_abnormal_date'], axis=1)
        
        # x_data, y_data, new_col = split_x_y_data(concat_df, OBP=28)
        # x_train, y_train, new_col = split_x_y_data(train_df, OBP=28)
        # x_test, y_test, new_col = split_x_y_data(test_df, OBP=28)
        
        #### Case 2 : Split ignore subject_id #####
        concat_df = concat_df.drop(['subject_id', 'unique_id', 'cohort_start_date', 'concept_date', 'first_abnormal_date'], axis=1)
    
        x_data, y_data, new_col = split_x_y_data(concat_df, OBP=7)
        x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.3, random_state=1, stratify=y_data) 
        
        c = Auto_lstm_attention()
        model = c.LSTM_attention_building(x_train, x_test, y_train, y_test)
        weights = c.class_balance_weight(output_domain_path, outcome_name, y_train)
        h, y_hat = c.early_stopping_prediction()
        c.classification_report(output_domain_path, outcome_name)
        c.model_performance_evaluation(output_dir, outcome_name)
        c.confusion_matrix_figure(output_domain_path, outcome_name)
        c.confusion_matrix_figure2(output_domain_path, outcome_name)
        AUC, ACC = c.ROC_AUC(output_domain_path, outcome_name)
        c.loss(output_domain_path, outcome_name)
        
        if_ = c.attention_heatmap(new_col, output_domain_path, outcome_name)
        accuracy = c.k_fold_cross_validation(x_data, y_data, output_domain_path, outcome_name)
        
        # (['AUC','ACC','import_f', 'k_fold'])
        model.save('{}/{}.h5'.format(output_domain_path, outcome_name))
        
    
        out = open('{}/output.txt'.format(output_dir),'a')
        
        out.write(str(outcome_name))
        out.write('///' )
        out.write(str(AUC ))
        out.write('///' )
        out.write(str(ACC ))
        out.write('///' )
        out.write(str(str(if_) ))
        out.write('///' )
        out.write(str(accuracy))
        out.write('\n')
        
        out.close()

    #except:
        print('except:', outcome_name)
        error.append(outcome_name)
    
print(error)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# (202, 7, 25) (202, 1) 25
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 7, 25)]      0
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 7, 20)        3680        input_1[0][0]
# __________________________________________________________________________________________________
# last_hidden_state (Lambda)      (None, 20)           0           lstm[0][0]
# __________________________________________________________________________________________________
# attention_score_vec (Dense)     (None, 7, 20)        400         lstm[0][0]
# __________________________________________________________________________________________________
# attention_score (Dot)           (None, 7)            0           last_hidden_state[0][0]
#                                                                  attention_score_vec[0][0]
# __________________________________________________________________________________________________
# attention_weight (Activation)   (None, 7)            0           attention_score[0][0]
# __________________________________________________________________________________________________
# context_vector (Dot)            (None, 20)           0           lstm[0][0]
#                                                                  attention_weight[0][0]
# __________________________________________________________________________________________________
# attention_output (Concatenate)  (None, 40)           0           context_vector[0][0]
#                                                                  last_hidden_state[0][0]
# __________________________________________________________________________________________________
# attention_vector (Dense)        (None, 10)           400         attention_output[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            11          attention_vector[0][0]
# ==================================================================================================
# Total params: 4,491
# Trainable params: 4,491
# Non-trainable params: 0
# __________________________________________________________________________________________________
# {0: 0.592436974789916, 1: 3.2045454545454546}
# Epoch 1/300
# 5/5 [==============================] - 1s 105ms/step - loss: 1.8523 - accuracy: 0.8333 - val_loss: 0.2505 - val_accuracy: 0.9333
# Epoch 2/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.9466 - accuracy: 0.8333 - val_loss: 0.2612 - val_accuracy: 0.9333
# Epoch 3/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7241 - accuracy: 0.8333 - val_loss: 0.2918 - val_accuracy: 0.9333
# Epoch 4/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7184 - accuracy: 0.8333 - val_loss: 0.3095 - val_accuracy: 0.9333
# Epoch 5/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.
300
# 5/5 [==============================] - 0s 27ms/step - loss: 0.5155 - accuracy: 0.8333 - val_loss: 0.2393 - val_accuracy: 0.9333
# Epoch 37/300
# 5/5 [==============================] - 0s 46ms/step - loss: 0.5143 - accuracy: 0.8333 - val_loss: 0.2381 - val_accuracy: 0.9333
# Epoch 38/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5104 - accuracy: 0.8333 - val_loss: 0.2432 - val_accuracy: 0.9333
# Epoch 39/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.5083 - accuracy: 0.8413 - val_loss: 0.2538 - val_accuracy: 0.9333
# Epoch 40/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.5075 - accuracy: 0.8413 - val_loss: 0.2548 - val_accuracy: 0.9333
# Epoch 41/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.5060 - accuracy: 0.8413 - val_loss: 0.2448 - val_accuracy: 0.9333
# Epoch 42/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5020 - accuracy: 0.8413 - val_loss: 0.2441 - val_accuracy: 0.9333
# Epoch 43/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5006 - accuracy: 0.8413 - val_loss: 0.2450 - val_accuracy: 0.9333
# Epoch 44/300
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4981 - accuracy: 0.8413 - val_loss: 0.2428 - val_accuracy: 0.9333
# Epoch 45/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4965 - accuracy: 0.8413 - val_loss: 0.2426 - val_accuracy: 0.9333
# Epoch 46/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4946 - accuracy: 0.8492 - val_loss: 0.2492 - val_accuracy: 0.9333
# Epoch 47/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4915 - accuracy: 0.8492 - val_loss: 0.2464 - val_accuracy: 0.9333
# Epoch 48/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4904 - accuracy: 0.8492 - val_loss: 0.2416 - val_accuracy: 0.9333
# Epoch 49/300
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4884 - accuracy: 0.8492 - val_loss: 0.2382 - val_accuracy: 0.9333
# Epoch 50/300
# 5/5 [==============================] - 0s 20ms/step - loss: 0.4870 - accuracy: 0.8492 - val_loss: 0.2448 - val_accuracy: 0.9333
# Epoch 51/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4844 - accuracy: 0.8651 - val_loss: 0.2473 - val_accuracy: 0.9333
# Epoch 52/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.4831 - accuracy: 0.8651 - val_loss: 0.2476 - val_accuracy: 0.9333
# Epoch 53/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4803 - accuracy: 0.8651 - val_loss: 0.2418 - val_accuracy: 0.9333
# Epoch 54/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4786 - accuracy: 0.8651 - val_loss: 0.2404 - val_accuracy: 0.9333
# Epoch 55/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4766 - accuracy: 0.8651 - val_loss: 0.2419 - val_accuracy: 0.9333
# Epoch 56/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.4749 - accuracy: 0.8651 - val_loss: 0.2478 - val_accuracy: 0.9333
# Epoch 57/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4740 - accuracy: 0.8571 - val_loss: 0.2511 - val_accuracy: 0.9333
# Epoch 58/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4715 - accuracy: 0.8492 - val_loss: 0.2446 - val_accuracy: 0.9333
# Epoch 59/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4689 - accuracy: 0.8571 - val_loss: 0.2364 - val_accuracy: 0.9333
# Epoch 60/300
# 5/5 [==============================] - 0s 28ms/step - loss: 0.4683 - accuracy: 0.8571 - val_loss: 0.2266 - val_accuracy: 0.9333
# Epoch 61/300
# 5/5 [==============================] - 0s 24ms/step - loss: 0.4672 - accuracy: 0.8571 - val_loss: 0.2265 - val_accuracy: 0.9333
# Epoch 62/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4647 - accuracy: 0.8651 - val_loss: 0.2461 - val_accuracy: 0.9333
# Epoch 63/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4634 - accuracy: 0.8571 - val_loss: 0.2444 - val_accuracy: 0.9333
# Epoch 64/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4620 - accuracy: 0.8571 - val_loss: 0.2428 - val_accuracy: 0.9333
# Epoch 65/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4597 - accuracy: 0.8571 - val_loss: 0.2324 - val_accuracy: 0.9333
# Epoch 66/300
# 5/5 [==============================] - 0s 35ms/step - loss: 0.
300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2486 - accuracy: 0.9127 - val_loss: 0.1845 - val_accuracy: 0.9333
# Epoch 284/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2484 - accuracy: 0.9127 - val_loss: 0.1923 - val_accuracy: 0.9333
# Epoch 285/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2474 - accuracy: 0.9048 - val_loss: 0.1881 - val_accuracy: 0.9333
# Epoch 286/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2431 - accuracy: 0.9286 - val_loss: 0.1829 - val_accuracy: 0.9333
# Epoch 287/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2426 - accuracy: 0.9286 - val_loss: 0.1774 - val_accuracy: 0.9333
# Epoch 288/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2478 - accuracy: 0.9048 - val_loss: 0.1736 - val_accuracy: 0.9333
# Epoch 289/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2443 - accuracy: 0.9048 - val_loss: 0.2036 - val_accuracy: 0.9333
# Epoch 290/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2435 - accuracy: 0.9206 - val_loss: 0.1815 - val_accuracy: 0.9333
# Epoch 291/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2454 - accuracy: 0.9286 - val_loss: 0.1935 - val_accuracy: 0.9333
# Epoch 292/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2462 - accuracy: 0.9048 - val_loss: 0.2014 - val_accuracy: 0.9333
# Epoch 293/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2410 - accuracy: 0.9127 - val_loss: 0.1871 - val_accuracy: 0.9333
# Epoch 294/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2413 - accuracy: 0.9286 - val_loss: 0.1750 - val_accuracy: 0.9333
# Epoch 295/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2478 - accuracy: 0.9206 - val_loss: 0.1753 - val_accuracy: 0.9333
# Epoch 296/300
# 5/5 [==============================] - 0s 16ms/step - loss: 0.2441 - accuracy: 0.9048 - val_loss: 0.2065 - val_accuracy: 0.9333
# Epoch 297/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.2424 - accuracy: 0.9127 - val_loss: 0.2050 - val_accuracy: 0.9333
# Epoch 298/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.2446 - accuracy: 0.9048 - val_loss: 0.1914 - val_accuracy: 0.9333
# Epoch 299/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2443 - accuracy: 0.9206 - val_loss: 0.1833 - val_accuracy: 0.9333
# Epoch 300/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.2403 - accuracy: 0.9206 - val_loss: 0.1967 - val_accuracy: 0.9333
#               precision    recall  f1-score   support
#
#      label 0       0.92      0.88      0.90        52
#      label 1       0.45      0.56      0.50         9
#
#     accuracy                           0.84        61
#    macro avg       0.69      0.72      0.70        61
# weighted avg       0.85      0.84      0.84        61
#
# Normalized confusion matrix
# [[0.88461538 0.11538462]
#  [0.44444444 0.55555556]]
# AUC: 0.7724
# ACC: 83.607
# Index(['morphine', 'celecoxib', 'Base excess in Arterial blood by calculation',
#        'Platelets [#/volume] in Blood',
#        'Bicarbonate [Moles/volume] in Arterial blood',
#        'Thyrotropin [Units/volume] in Serum or Plasma',
#        'Carbon dioxide, total [Moles/volume] in Arterial blood',
#        'Large unstained cells/100 leukocytes in Blood',
#        'Carbon dioxide, total [Moles/volume] in Serum or Plasma',
#        'Oxygen content in Arterial blood',
#        'aPTT in Platelet poor plasma by Coagulation assay',
#        'Monocytes/100 leukocytes in Blood',
#        'Sodium [Moles/volume] in Serum or Plasma', 'pH of Arterial blood',
#        'Albumin [Mass/volume] in Serum or Plasma', 'MCV [Entitic volume]',
#        'Gamma glutamyl transferase [Enzymatic activity/volume] in Serum or Plasma',
#        'Base excess in Extracellular fluid by calculation',
#        '500 ML glucose 50 MG/ML Injection',
#        'X-ray of chest anteroposterior view',
#        'X-ray of chest posteroanterior view',
#        'Erythrocyte mean corpuscular hemoglobin',
#        'rebamipide 100 MG Oral Tablet'],
#       dtype='object')
# [[5.73520316e-03 8.22129101e-03 4.21008691e-02 6.64813668e-02
#   8.36427510e-02 1.47729397e-01 6.46089077e-01]
#  [2.24748114e-03 4.25444217e-03 8.15699529e-03 1.54519062e-02
#   2.82079838e-02 4.86645848e-02 8.93016636e-01]
#  [5.14117637e-05 1.68192113e-04 2.54043657e-03 2.76069120e-02
#   1.20865144e-01 3.02165300e-01 5.46602607e-01]
#  [9.66355391e-03 2.46212296e-02 5.17105460e-02 9.59267616e-02
#   1.63756877e-01 2.61690885e-01 3.92630100e-01]
#  [4.75800969e-02 6.14936948e-02 8.27334002e-02 1.14482440e-01
#   1.60454631e-01 2.24326432e-01 3.08929324e-01]
# ...
# Epoch 102/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1388 - accuracy: 0.9194 - val_loss: 1.9611 - val_accuracy: 0.5714
# Epoch 103/300
# 5/5 [==============================] - 0s 13ms/step - loss: 0.1413 - accuracy: 0.9032 - val_loss: 1.9317 - val_accuracy: 0.6429
# Epoch 104/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1393 - accuracy: 0.9274 - val_loss: 2.0368 - val_accuracy: 0.5714
# Epoch 105/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1382 - accuracy: 0.9032 - val_loss: 2.7460 - val_accuracy: 0.5714
# Epoch 106/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1420 - accuracy: 0.9032 - val_loss: 2.6533 - val_accuracy: 0.6429
# Epoch 107/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.1382 - accuracy: 0.9355 - val_loss: 2.6307 - val_accuracy: 0.6429
# Epoch 00107: early stopping
#               precision    recall  f1-score   support
#
#      label 0       0.89      0.78      0.83        40
#      label 1       0.64      0.80      0.71        20
#
#     accuracy                           0.78        60
#    macro avg       0.76      0.79      0.77        60
# weighted avg       0.80      0.78      0.79        60
#
# Normalized confusion matrix
# [[0.775 0.225]
#  [0.2   0.8  ]]
# AUC: 0.7806
# ACC: 78.333
# Index(['Arthropathy', 'furosemide', 'celecoxib',
#        'Glucose [Mass/volume] in Blood', 'Hemoglobin [Mass/volume] in Blood',
#        'Base excess in Arterial blood by calculation',
#        'Calcium [Mass/volume] in Serum or Plasma',
#        'Platelets [#/volume] in Blood',
#        'Bicarbonate [Moles/volume] in Arterial blood',
#        'Hematocrit [Volume Fraction] of Blood',
#        'Carbon dioxide, total [Moles/volume] in Arterial blood',
#        'Carbon dioxide, total [Moles/volume] in Serum or Plasma',
#        'Monocytes/100 leukocytes in Blood', 'pH of Arterial blood',
#        'Protein [Mass/volume] in Serum or Plasma',
#        'Albumin [Mass/volume] in Serum or Plasma', 'MCV [Entitic volume]',
#        'Prothrombin time (PT) actual/Normal',
#        'Computed tomography of abdomen and pelvis with contrast',
#        'Base excess in Extracellular fluid by calculation',
#        'X-ray of chest anteroposterior view', 'Plain X-ray of hip',
#        'Plain X-ray of right hip', 'Plain X-ray of bilateral hips',
#        'Erythrocyte mean corpuscular hemoglobin',
#        'Ursodeoxycholate 100 MG Oral Tablet [URSA]'],
#       dtype='object')
# [[1.03121931e-02 1.42758572e-02 1.81748010e-02 5.02182469e-02
#   1.30090520e-01 2.79674590e-01 4.97253746e-01]
#  'Computed tomography of abdomen and pelvis with contrast'
#  'Base excess in Extracellular fluid by calculation'
#  'X-ray of chest anteroposterior view' 'Plain X-ray of hip'
#  'Plain X-ray of right hip' 'Plain X-ray of bilateral hips'
#  'Erythrocyte mean corpuscular hemoglobin'
#  'Ursodeoxycholate 100 MG Oral Tablet [URSA]']
# importance feature: Plain X-ray of hip
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/50
# 6/6 [==============================] - 0s 76ms/step - loss: 8.4910 - accuracy: 0.6268 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/50
# 6/6 [==============================] - 0s 9ms/step - loss: 8.4427 - accuracy: 0.6268 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/50
# 6/6 [==============================] - 0s 13ms/step - loss: 8.4398 - accuracy: 0.6268 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/50
# 6/6 [==============================] - 0s 10ms/step - loss: 7.7077 - accuracy: 0.6268 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/50
# 6/6 [==============================] - 0s 36ms/step - loss: 6.0007 - accuracy: 0.6268 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 6/50
# 6/6 [==============================] - 0s 9ms/step - loss: 3.9376 - accuracy: 0.6268 - val_loss: 0.0877 - val_accuracy: 1.0000
# Epoch 7/50
# 6/6 [==============================] - 0s 9ms/step - loss: 1.5707 - accuracy: 0.6197 - val_loss: 0.3097 - val_accuracy: 1.0000
# Epoch 8/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.7197 - accuracy: 0.6408 - val_loss: 0.6158 - val_accuracy: 0.6875
# Epoch 9/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6952 - accuracy: 0.5634 - val_loss: 0.8334 - val_accuracy: 0.2500
# Epoch 10/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.7171 - accuracy: 0.3944 - val_loss: 0.8912 - val_accuracy: 0.1250
# Epoch 11/50
# 6/6 [==============================] - 0s 18ms/step - loss: 0.7069 - accuracy: 0.4366 - val_loss: 0.8280 - val_accuracy: 0.3750
# Epoch 00011: early stopping
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/50
# 6/6 [==============================] - 0s 79ms/step - loss: 3.6859 - accuracy: 0.6268 - val_loss: 0.2037 - val_accuracy: 0.9375
# Epoch 2/50
# 6/6 [==============================] - 0s 9ms/step - loss: 2.1665 - accuracy: 0.7183 - val_loss: 0.3812 - val_accuracy: 0.8125
# Epoch 3/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.8420 - accuracy: 0.6479 - val_loss: 0.7596 - val_accuracy: 0.4375
# Epoch 4/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6360 - accuracy: 0.7042 - val_loss: 0.9655 - val_accuracy: 0.4375
# Epoch 5/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6295 - accuracy: 0.7042 - val_loss: 0.8123 - val_accuracy: 0.4375
# Epoch 6/50
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6015 - accuracy: 0.7394 - val_loss: 0.7269 - val_accuracy: 0.5625
# Epoch 7/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5868 - accuracy: 0.7535 - val_loss: 0.6835 - val_accuracy: 0.6250
# Epoch 8/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5758 - accuracy: 0.7606 - val_loss: 0.7028 - val_accuracy: 0.6250
# Epoch 9/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5626 - accuracy: 0.7676 - val_loss: 0.6903 - val_accuracy: 0.6875
# Epoch 10/50
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5543 - accuracy: 0.7606 - val_loss: 0.6934 - val_accuracy: 0.6875
# Epoch 11/50
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5379 - accuracy: 0.7676 - val_loss: 0.7296 - val_accuracy: 0.6875
# Epoch 00011: early stopping
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/50
# 6/6 [==============================] - 1s 84ms/step - loss: 2.0697 - accuracy: 0.5915 - val_loss: 0.5426 - val_accuracy: 0.8125
# Epoch 2/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.9337 - accuracy: 0.4366 - val_loss: 0.8245 - val_accuracy: 0.1875
# Epoch 3/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.8497 - accuracy: 0.3803 - val_loss: 0.9241 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7889 - accuracy: 0.3873 - val_loss: 0.8994 - val_accuracy: 0.1875
# Epoch 5/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7210 - accuracy: 0.4437 - val_loss: 0.8212 - val_accuracy: 0.2500
# Epoch 6/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6745 - accuracy: 0.5423 - val_loss: 0.7849 - val_accuracy: 0.3750
# Epoch 7/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6397 - accuracy: 0.6127 - val_loss: 0.7517 - val_accuracy: 0.5000
# Epoch 8/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6139 - accuracy: 0.6338 - val_loss: 0.6886 - val_accuracy: 0.6250
# Epoch 9/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5894 - accuracy: 0.6972 - val_loss: 0.6267 - val_accuracy: 0.6875
# Epoch 10/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5740 - accuracy: 0.7183 - val_loss: 0.5975 - val_accuracy: 0.8125
# Epoch 11/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5537 - accuracy: 0.7465 - val_loss: 0.6026 - val_accuracy: 0.6875
# Epoch 00011: early stopping
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/50
# 6/6 [==============================] - 1s 135ms/step - loss: 1.3765 - accuracy: 0.6154 - val_loss: 0.5621 - val_accuracy: 0.6875
# Epoch 2/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.9255 - accuracy: 0.4406 - val_loss: 0.8829 - val_accuracy: 0.3750
# Epoch 3/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.8218 - accuracy: 0.3846 - val_loss: 0.8761 - val_accuracy: 0.3750
# Epoch 4/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7532 - accuracy: 0.4406 - val_loss: 0.7750 - val_accuracy: 0.3125
# Epoch 5/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.7027 - accuracy: 0.5734 - val_loss: 0.8115 - val_accuracy: 0.2500
# Epoch 6/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6675 - accuracy: 0.6224 - val_loss: 0.7860 - val_accuracy: 0.3125
# Epoch 7/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6392 - accuracy: 0.6783 - val_loss: 0.7414 - val_accuracy: 0.4375
# Epoch 8/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6167 - accuracy: 0.7203 - val_loss: 0.7213 - val_accuracy: 0.4375
# Epoch 9/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6045 - accuracy: 0.7343 - val_loss: 0.8000 - val_accuracy: 0.3750
# Epoch 10/50
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5816 - accuracy: 0.7063 - val_loss: 0.9552 - val_accuracy: 0.3125
# Epoch 11/50
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5701 - accuracy: 0.7133 - val_loss: 0.9514 - val_accuracy: 0.3125
# Epoch 00011: early stopping
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/50
# 6/6 [==============================] - 0s 79ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 2/50
# 6/6 [==============================] - 0s 11ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 3/50
# 6/6 [==============================] - 0s 9ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/50
# 6/6 [==============================] - 0s 9ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/50
# 6/6 [==============================] - 0s 13ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 6/50
# 6/6 [==============================] - 0s 12ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 7/50
# 6/6 [==============================] - 0s 13ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 8/50
# 6/6 [==============================] - 0s 11ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 9/50
# 6/6 [==============================] - 0s 10ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 10/50
# 6/6 [==============================] - 0s 10ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 11/50
# 6/6 [==============================] - 0s 9ms/step - loss: 8.5754 - accuracy: 0.6224 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 00011: early stopping
# 100%|██████████| 2/2 [01:24<00:00, 42.15s/it]
# [0.45, 0.55, 0.675, 0.6923076923076923, 0.6666666666666666]
# except: abnormal_nephrotoxicity
# ['abnormal_hepatotoxicity', 'abnormal_nephrotoxicity']
